# %%
print('Hello World')
# Out:
# Hello World

# %%
a = 1

# %%
b = 2

# %%
b = a
a = b

# %%
print (a)
# Out:
# 1

# %%
print (b)
# Out:
# 1

# %%
a = 2

# %%
b = 1
print (a)
# Out:
# 2

# %%
print (b)
# Out:
# 1
